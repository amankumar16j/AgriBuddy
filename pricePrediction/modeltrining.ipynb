# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestRegressor
import joblib
from sklearn.preprocessing import StandardScaler


# Necessary imports 
import numpy as np 
import pandas as pd 
import xgboost as xg 
from sklearn.model_selection import train_test_split 
from sklearn.metrics import mean_squared_error as MSE

# %%
annual_rainfall = [29, 21, 37.5, 30.7, 52.6, 150, 299, 251.7, 179.2, 70.5, 39.8, 10.9]

# %%
commodity_dict = {
    "arhar": "static/Arhar.csv",
    "cotton": "static/Cotton.csv",
    "gram": "static/Gram.csv",
    "masoor": "static/Masoor.csv",
    "moong": "static/Moong.csv",
    "sugarcane": "static/Sugarcane.csv",
    "sunflower": "static/Sunflower.csv",
    "wheat": "static/Wheat.csv"
}

# %%
i=0
for key,value in commodity_dict.items():
    data=pd.read_csv(value)
    data["type"]=i
    data.to_csv(value,index=False)
    i=i+1

# %%
xgb_r = xg.XGBRegressor(objective ='reg:linear', 
                  n_estimators = 10, seed = 123)

# %%
model=RandomForestRegressor(max_depth=3)
scaler=StandardScaler()

# %%
for key,value in commodity_dict.items():
    data=pd.read_csv(value)
    x=data.drop("WPI",axis=1)
    y=data["WPI"]
    x=scaler.fit_transform(x)
    print("training",key)
    xgb_r.fit(x, y)
# Out:
# training arhar
# training cotton
# c:\Python311\Lib\site-packages\xgboost\core.py:158: UserWarning: [22:13:39] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\objective\regression_obj.cu:227: reg:linear is now deprecated in favor of reg:squarederror.
#   warnings.warn(smsg, UserWarning)
# c:\Python311\Lib\site-packages\xgboost\core.py:158: UserWarning: [22:13:39] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\objective\regression_obj.cu:227: reg:linear is now deprecated in favor of reg:squarederror.
#   warnings.warn(smsg, UserWarning)
# ...

# %%
joblib.dump(model,"D:/smartindia/pricePrediction/pricePredmodel1.pkl")
# Out:
# ['D:/smartindia/pricePrediction/pricePredmodel1.pkl']

# %%
x=pd.DataFrame([20,2050,1.2,5])

# %%
x=x.T

# %%
xgb_r.predict(x)
# Out:
# array([145.43037], dtype=float32)

# %%
model1=RandomForestRegressor()

# %%
data=pd.read_csv("static/Barley.csv")

# %%
x=data.drop("WPI",axis=1)
y=data["WPI"]

# %%
model1.fit(x,y)
# Out:
# RandomForestRegressor()

# %%
x=pd.DataFrame([9,2024,179.2,2]).T

# %%
model1.predict(x)
# Out:
# c:\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# array([145.769])
